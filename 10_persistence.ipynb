# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatOpenAI()

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer=InMemorySaver()
workflow=graph.compile(checkpointer=checkpointer)

# %%
config1={"configurable":{"thread_id":"2"}}
workflow.invoke({'topic':'car'},config=config1)
# Out:
# {'topic': 'car',
#  'joke': "Why did the car break up with his girlfriend?\nBecause she couldn't handle his exhaust-ing personality!",
#  'explanation': 'This joke is a play on words, using the term "exhaust-ing" to describe the car\'s personality. In the context of cars, exhaust refers to the fumes that are released from the engine. So, the joke implies that the car\'s personality was so overwhelming or tiring that his girlfriend couldn\'t handle it, comparing it to dealing with a car\'s exhaust fumes.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with his girlfriend?\nBecause she couldn't handle his exhaust-ing personality!", 'explanation': 'This joke is a play on words, using the term "exhaust-ing" to describe the car\'s personality. In the context of cars, exhaust refers to the fumes that are released from the engine. So, the joke implies that the car\'s personality was so overwhelming or tiring that his girlfriend couldn\'t handle it, comparing it to dealing with a car\'s exhaust fumes.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f182-6942-8002-825d91bc0672'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T06:34:13.580205+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-e629-610c-8001-9b764a7420c4'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with his girlfriend?\nBecause she couldn't handle his exhaust-ing personality!", 'explanation': 'This joke is a play on words, using the term "exhaust-ing" to describe the car\'s personality. In the context of cars, exhaust refers to the fumes that are released from the engine. So, the joke implies that the car\'s personality was so overwhelming or tiring that his girlfriend couldn\'t handle it, comparing it to dealing with a car\'s exhaust fumes.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f182-6942-8002-825d91bc0672'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T06:34:13.580205+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-e629-610c-8001-9b764a7420c4'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with his girlfriend?\nBecause she couldn't handle his exhaust-ing personality!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-e629-610c-8001-9b764a7420c4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T06:34:12.390105+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-dd9c-6a55-8000-e1ead691ea61'}}, tasks=(PregelTask(id='d45f6a82-1340-0101-2c3e-1cce8994ad1d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using the term "exhaust-ing" to describe the car\'s personality. In the context of cars, exhaust refers to the fumes that are released from the engine. So, the joke implies that the car\'s personality was so overwhelming or tiring that his girlfriend couldn\'t handle it, comparing it to dealing with a car\'s exhaust fumes.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-dd9c-6a55-8000-e1ead691ea61'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T06:34:11.493734+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-dd9a-67cb-bfff-90838d100a70'}}, tasks=(PregelTask(id='24cc1c26-a300-405a-c9be-d8cfa18cb151', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with his girlfriend?\nBecause she couldn't handle his exhaust-ing personality!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-dd9a-67cb-bfff-90838d100a70'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T06:34:11.492853+00:00', parent_config=None, tasks=(PregelTask(id='bee7cb68-3af9-1484-5316-2140e9dab981', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=())]

# %%
config2={"configurable":{"thread_id":"3"}}
workflow.invoke({'topic':'computer'},config=config2)
# Out:
# {'topic': 'computer',
#  'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!',
#  'explanation': 'This joke plays on the double meaning of the word "Windows." In one sense, "Windows" refers to the operating system used by many computers. However, in a more literal sense, "Windows" also refers to the openings in a building that can be opened or closed for ventilation.\n\nSo, the joke is a playful twist on the idea that the computer was cold because it left its "Windows" (openings in the building) open, allowing cold air to come in and cool down the computer. It\'s a simple and lighthearted play on words that combines technology and humor.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'computer', 'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!', 'explanation': 'This joke plays on the double meaning of the word "Windows." In one sense, "Windows" refers to the operating system used by many computers. However, in a more literal sense, "Windows" also refers to the openings in a building that can be opened or closed for ventilation.\n\nSo, the joke is a playful twist on the idea that the computer was cold because it left its "Windows" (openings in the building) open, allowing cold air to come in and cool down the computer. It\'s a simple and lighthearted play on words that combines technology and humor.'}, next=(), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b83-0455-65ff-8002-2ae9519efad9'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T06:34:15.553984+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f86e-6fb5-8001-41b91f1ffc33'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history((config2)))
# Out:
# [StateSnapshot(values={'topic': 'computer', 'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!', 'explanation': 'This joke plays on the double meaning of the word "Windows." In one sense, "Windows" refers to the operating system used by many computers. However, in a more literal sense, "Windows" also refers to the openings in a building that can be opened or closed for ventilation.\n\nSo, the joke is a playful twist on the idea that the computer was cold because it left its "Windows" (openings in the building) open, allowing cold air to come in and cool down the computer. It\'s a simple and lighthearted play on words that combines technology and humor.'}, next=(), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b83-0455-65ff-8002-2ae9519efad9'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T06:34:15.553984+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f86e-6fb5-8001-41b91f1ffc33'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'computer', 'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f86e-6fb5-8001-41b91f1ffc33'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T06:34:14.306180+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f1c3-66c6-8000-c80568da6f00'}}, tasks=(PregelTask(id='f76a6ecf-2c1e-7164-305c-8d8c56fbbad1', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the double meaning of the word "Windows." In one sense, "Windows" refers to the operating system used by many computers. However, in a more literal sense, "Windows" also refers to the openings in a building that can be opened or closed for ventilation.\n\nSo, the joke is a playful twist on the idea that the computer was cold because it left its "Windows" (openings in the building) open, allowing cold air to come in and cool down the computer. It\'s a simple and lighthearted play on words that combines technology and humor.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'computer'}, next=('generate_joke',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f1c3-66c6-8000-c80568da6f00'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T06:34:13.606771+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f1c1-6f51-bfff-5cc8d9dc13e8'}}, tasks=(PregelTask(id='dd554760-825f-c9c9-5b6b-f99a4d4143c8', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f104b82-f1c1-6f51-bfff-5cc8d9dc13e8'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T06:34:13.606172+00:00', parent_config=None, tasks=(PregelTask(id='caf412ea-109c-5150-4ada-57bc9e339d13', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'computer'}),), interrupts=())]

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f104a2b-c7b7-648f-8005-42b76d16e901"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
workflow.invoke(None, config={"configurable": {"thread_id": "2", "checkpoint_id": "1f104a2b-c7b7-648f-8005-42b76d16e901"}})
# Out:
# ---------------------------------------------------------------------------
# EmptyInputError                           Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 workflow.invoke(None, config={"configurable": {"thread_id": "2", "checkpoint_id": "1f104a2b-c7b7-648f-8005-42b76d16e901"}})
#
# File c:\Users\gdinesh\source\repos\AI\Langgraph\myenv\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File c:\Users\gdinesh\source\repos\AI\Langgraph\myenv\Lib\site-packages\langgraph\pregel\main.py:2582, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2579 runtime = parent_runtime.merge(runtime)
#    2580 config[CONF][CONFIG_KEY_RUNTIME] = runtime
# -> 2582 with SyncPregelLoop(
#    2583     input,
#    2584     stream=StreamProtocol(stream.put, stream_modes),
#    2585     config=config,
#    2586     store=store,
#    2587     cache=cache,
#    2588     checkpointer=checkpointer,
#    2589     nodes=self.nodes,
#    2590     specs=self.channels,
#    2591     output_keys=output_keys,
#    2592     input_keys=self.input_channels,
#    2593     stream_keys=self.stream_channels_asis,
#    2594     interrupt_before=interrupt_before_,
#    2595     interrupt_after=interrupt_after_,
#    2596     manager=run_manager,
#    2597     durability=durability_,
#    2598     trigger_to_nodes=self.trigger_to_nodes,
#    2599     migrate_checkpoint=self._migrate_checkpoint,
#    2600     retry_policy=self.retry_policy,
#    2601     cache_policy=self.cache_policy,
#    2602 ) as loop:
#    2603     # create runner
#    2604     runner = PregelRunner(
#    2605         submit=config[CONF].get(
#    2606             CONFIG_KEY_RUNNER_SUBMIT, weakref.WeakMethod(loop.submit)
#    (...)   2609         node_finished=config[CONF].get(CONFIG_KEY_NODE_FINISHED),
#    2610     )
#    2611     # enable subgraph streaming
#
# File c:\Users\gdinesh\source\repos\AI\Langgraph\myenv\Lib\site-packages\langgraph\pregel\_loop.py:1122, in SyncPregelLoop.__enter__(self)
#    1120 self.stop = self.step + self.config["recursion_limit"] + 1
#    1121 self.checkpoint_previous_versions = self.checkpoint["channel_versions"].copy()
# -> 1122 self.updated_channels = self._first(
#    1123     input_keys=self.input_keys,
#    1124     updated_channels=set(self.checkpoint.get("updated_channels"))  # type: ignore[arg-type]
#    1125     if self.checkpoint.get("updated_channels")
#    1126     else None,
#    1127 )
#    1129 return self
#
# File c:\Users\gdinesh\source\repos\AI\Langgraph\myenv\Lib\site-packages\langgraph\pregel\_loop.py:725, in PregelLoop._first(self, input_keys, updated_channels)
#     723     self._put_checkpoint({"source": "input"})
#     724 elif CONFIG_KEY_RESUMING not in configurable:
# --> 725     raise EmptyInputError(f"Received no input for {input_keys}")
#     726 # update config
#     727 if not self.is_nested:
#
# EmptyInputError: Received no input for __start__

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used ironically to create a pun. Gaslighting is a form of manipulation where someone makes someone else question their own reality, often by denying or twisting the truth. In this context, the joke suggests that the car literally couldn\'t handle the mechanic constantly manipulating and lying to it, so it decided to "break up" with the mechanic. The humor comes from the clever play on words by using "gaslighting" in a literal sense related to a car\'s fuel.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a67-8031-6c94-8006-b1fae517f985'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:27:24.974796+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke plays on the double meaning of "gaslighting", which typically refers to manipulation or psychological manipulation where a person makes someone question their reality. In this case, the joke implies that the car could not handle the mechanic constantly manipulating its engine by gaslighting it. It is a play on words that uses the term "gaslighting" in a humorous way to suggest that the car literally cannot handle the mechanic using gaslighting techniques on it.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a56-38b0-68a2-8006-31f384c1f1f6'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:19:41.136693+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-d4d1-6e00-8006-5736884b90ba'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:00:43.235665+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-02-08T04:00:41.861634+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, tasks=(PregelTask(id='473e7aa7-817a-a4b5-8db6-c52c3fb6e80a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-02-08T04:00:41.205370+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, tasks=(PregelTask(id='b7cafb1b-a38c-f84b-3303-f1ef1d0e612d', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!"}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2026-02-08T04:00:41.204716+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, tasks=(PregelTask(id='6968a7c2-8d72-9c53-60b5-1f23f02d71fe', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T04:00:05.173985+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T04:00:03.695652+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, tasks=(PregelTask(id='09d71d8a-bb45-302c-1e8a-62fa6b4fa4fb', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T04:00:03.045495+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, tasks=(PregelTask(id='fa06bc69-7b9f-6ccc-596d-a560b4e0031b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T04:00:03.044798+00:00', parent_config=None, tasks=(PregelTask(id='ca0ccc61-32cb-d3e5-0410-fb8d46355c49', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=())]

# %%
workflow.update_state(
    config={
        "configurable": {
            "thread_id": "2",
            "checkpoint_id": "1f104a2b-c7b7-648f-8005-42b76d16e901",
            "checkpoint_ns": ""
        }
    },
    values={"topic": "samosa"}
)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f104a6c-1848-6456-8006-c8b44f0a7803'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a6c-1848-6456-8006-c8b44f0a7803'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:29:28.296546+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(PregelTask(id='63c76796-cb8c-0d41-da94-cd8fa3b80463', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used ironically to create a pun. Gaslighting is a form of manipulation where someone makes someone else question their own reality, often by denying or twisting the truth. In this context, the joke suggests that the car literally couldn\'t handle the mechanic constantly manipulating and lying to it, so it decided to "break up" with the mechanic. The humor comes from the clever play on words by using "gaslighting" in a literal sense related to a car\'s fuel.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a67-8031-6c94-8006-b1fae517f985'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:27:24.974796+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke plays on the double meaning of "gaslighting", which typically refers to manipulation or psychological manipulation where a person makes someone question their reality. In this case, the joke implies that the car could not handle the mechanic constantly manipulating its engine by gaslighting it. It is a play on words that uses the term "gaslighting" in a humorous way to suggest that the car literally cannot handle the mechanic using gaslighting techniques on it.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a56-38b0-68a2-8006-31f384c1f1f6'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:19:41.136693+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-d4d1-6e00-8006-5736884b90ba'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:00:43.235665+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-02-08T04:00:41.861634+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, tasks=(PregelTask(id='473e7aa7-817a-a4b5-8db6-c52c3fb6e80a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-02-08T04:00:41.205370+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, tasks=(PregelTask(id='b7cafb1b-a38c-f84b-3303-f1ef1d0e612d', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!"}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2026-02-08T04:00:41.204716+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, tasks=(PregelTask(id='6968a7c2-8d72-9c53-60b5-1f23f02d71fe', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T04:00:05.173985+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T04:00:03.695652+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, tasks=(PregelTask(id='09d71d8a-bb45-302c-1e8a-62fa6b4fa4fb', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T04:00:03.045495+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, tasks=(PregelTask(id='fa06bc69-7b9f-6ccc-596d-a560b4e0031b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T04:00:03.044798+00:00', parent_config=None, tasks=(PregelTask(id='ca0ccc61-32cb-d3e5-0410-fb8d46355c49', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=())]

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f104a6c-1848-6456-8006-c8b44f0a7803"}})
# Out:
# {'topic': 'samosa',
#  'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!",
#  'explanation': 'In this joke, "gaslighting" is a term used to describe a form of manipulation where someone is made to doubt their own perception, memories, and sanity. In the context of the joke, "gaslighting" is used as a pun to refer to the mechanic constantly telling false information about the car or its issues. The car breaks up with the mechanic because it is unable to handle being constantly lied to and manipulated.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, "gaslighting" is a term used to describe a form of manipulation where someone is made to doubt their own perception, memories, and sanity. In the context of the joke, "gaslighting" is used as a pun to refer to the mechanic constantly telling false information about the car or its issues. The car breaks up with the mechanic because it is unable to handle being constantly lied to and manipulated.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a78-11f5-634a-8007-9e9d5197687d'}}, metadata={'source': 'loop', 'step': 7, 'parents': {}}, created_at='2026-02-08T04:34:49.755925+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a6c-1848-6456-8006-c8b44f0a7803'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke plays on two meanings of the word "gaslighting." In the context of a car and mechanic relationship, "gaslighting" is used to describe the mechanic constantly manipulating or misleading the car about its issues or needed repairs. However, "gaslighting" also refers to a form of psychological manipulation where a person tries to make someone doubt their own thoughts, feelings, or perceptions. The joke humorously suggests that the car ended the relationship with its mechanic because it couldn\'t handle the constant deceit and manipulation.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a77-15dd-6976-8006-4118b43ae91f'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:34:23.322137+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words that uses the term "gaslighting." In a relationship, gaslighting refers to manipulating someone into doubting their own thoughts, feelings, and reality. In this joke, the car broke up with its mechanic because it couldn\'t handle the constant gaslighting - in this case, the mechanic was constantly manipulating the car into thinking there was something wrong with it, even when there wasn\'t. The joke is humorous because it applies a serious concept like gaslighting to a lighthearted situation involving a car and its mechanic.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a75-82e8-6d2d-8006-35dbd71f8164'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:33:41.069123+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'samosa', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a6c-1848-6456-8006-c8b44f0a7803'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:29:28.296546+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(PregelTask(id='63c76796-cb8c-0d41-da94-cd8fa3b80463', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'In this joke, "gaslighting" is a term used to describe a form of manipulation where someone is made to doubt their own perception, memories, and sanity. In the context of the joke, "gaslighting" is used as a pun to refer to the mechanic constantly telling false information about the car or its issues. The car breaks up with the mechanic because it is unable to handle being constantly lied to and manipulated.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used ironically to create a pun. Gaslighting is a form of manipulation where someone makes someone else question their own reality, often by denying or twisting the truth. In this context, the joke suggests that the car literally couldn\'t handle the mechanic constantly manipulating and lying to it, so it decided to "break up" with the mechanic. The humor comes from the clever play on words by using "gaslighting" in a literal sense related to a car\'s fuel.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a67-8031-6c94-8006-b1fae517f985'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:27:24.974796+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke plays on the double meaning of "gaslighting", which typically refers to manipulation or psychological manipulation where a person makes someone question their reality. In this case, the joke implies that the car could not handle the mechanic constantly manipulating its engine by gaslighting it. It is a play on words that uses the term "gaslighting" in a humorous way to suggest that the car literally cannot handle the mechanic using gaslighting techniques on it.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a56-38b0-68a2-8006-31f384c1f1f6'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:19:41.136693+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-d4d1-6e00-8006-5736884b90ba'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-02-08T04:00:43.235665+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c7b7-648f-8005-42b76d16e901'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-02-08T04:00:41.861634+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, tasks=(PregelTask(id='473e7aa7-817a-a4b5-8db6-c52c3fb6e80a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'In this joke, the term "gaslighting" is used in a humorous way to imply that the mechanic was constantly manipulating or deceiving the car. Gaslighting is a form of psychological manipulation in which a person seeks to make another person doubt their own perceptions and reality. In this case, the joke suggests that the car decided to end its relationship with the mechanic because it couldn\'t handle the constant deceit and manipulation. It turns a serious issue into a lighthearted and silly scenario.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c175-611f-8004-a158749421b9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-02-08T04:00:41.205370+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, tasks=(PregelTask(id='b7cafb1b-a38c-f84b-3303-f1ef1d0e612d', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with its mechanic? Because it just couldn't handle the constant gaslighting!"}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2b-c173-67ad-8003-93f63c6003ee'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2026-02-08T04:00:41.204716+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, tasks=(PregelTask(id='6968a7c2-8d72-9c53-60b5-1f23f02d71fe', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!", 'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-69d5-6d4e-8002-4f2cbf30e88d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T04:00:05.173985+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'car', 'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5bbc-69fc-8001-f6056a25706f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T04:00:03.695652+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, tasks=(PregelTask(id='09d71d8a-bb45-302c-1e8a-62fa6b4fa4fb', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using the idea of a romantic relationship between a car and a gas station. In this scenario, the car "breaks up" with the gas station because they are constantly arguing about fueling. This is funny because cars need gas from the station to function, so it is humorous to imagine them having relationship problems over something so essential. The joke also plays on the common phrase "fueling arguments," meaning disagreements or conflicts related to refueling a car.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'car'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5589-6504-8000-31f3007d8f07'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T04:00:03.045495+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, tasks=(PregelTask(id='fa06bc69-7b9f-6ccc-596d-a560b4e0031b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the car break up with the gas station? Because it couldn't handle their constant fueling arguments!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f104a2a-5587-699b-bfff-c10eac3fd57d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T04:00:03.044798+00:00', parent_config=None, tasks=(PregelTask(id='ca0ccc61-32cb-d3e5-0410-fb8d46355c49', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'car'}),), interrupts=())]

# %% [markdown]
# Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(10)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ✅ Step 3 executed
#
# ✅ Final State: {'input': 'start', 'step1': 'done', 'step2': 'done'}

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba6-f310-6864-8003-2f72ae02dc01'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-02-08T06:50:20.110843+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba6-f30e-6029-8002-571962c8fdc4'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=('step_3',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba6-f30e-6029-8002-571962c8fdc4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-02-08T06:50:20.109804+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72cb-689b-8001-594d25b0f612'}}, tasks=(PregelTask(id='cd406f48-15b5-f877-51a3-beda994efa21', name='step_3', path=('__pregel_pull', 'step_3'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72cb-689b-8001-594d25b0f612'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-02-08T06:49:39.817275+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72c9-674b-8000-f5d8e0344504'}}, tasks=(PregelTask(id='9388aa59-c90c-9bd8-fea6-6c0aed71d885', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result={'step2': 'done'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72c9-674b-8000-f5d8e0344504'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-08T06:49:39.816420+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72c5-6c67-bfff-eddf9253530a'}}, tasks=(PregelTask(id='9cb51eb4-ca8b-ebd5-fa14-166173a9b77a', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f104ba5-72c5-6c67-bfff-eddf9253530a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-02-08T06:49:39.814915+00:00', parent_config=None, tasks=(PregelTask(id='ff77ac52-b0c1-e97f-038a-4a46b25aa266', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=())]
