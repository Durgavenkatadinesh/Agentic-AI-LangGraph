# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model=ChatOpenAI()

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state: BlogState) -> BlogState:
    
    # fetch title
    title=state['title']
    
    # call the llm gen outline
    prompt=f'Generate a detailed blog outline for a blog on the topic - {title}'
    outline=model.invoke(prompt).content
    
    # update state
    state['outline']=outline
    
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    
    title=state['title']
    outline=state['outline']
    
    prompt=f'Write a detailed blog post on the title - {title} using the following outline \n {outline}'
    
    content = model.invoke(prompt).content
    
    state['content']=content
    
    return state

# %%
graph=StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow=graph.compile()

# %%
initial_state={'title': 'Rise of AI in India'}

final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'I. Introduction\n- Brief history of artificial intelligence (AI) and its growth worldwide\n- Explanation of what AI is and its various applications\n\nII. Overview of AI in India\n- Current state of AI in India\n- Statistics on AI adoption in different industries\n- Major players in the Indian AI market\n\nIII. Growth of AI in India\n- Factors contributing to the rise of AI in India\n- Government initiatives and policies promoting AI\n- Investments in AI startups and research institutions\n\nIV. Applications of AI in India\n- AI in healthcare\n- AI in agriculture\n- AI in education\n- AI in finance\n- AI in manufacturing\n- AI in e-commerce\n\nV. Challenges and Opportunities\n- Challenges faced by AI in India\n- Opportunities for growth and development in the Indian AI market\n- Ethical considerations and concerns related to AI\n\nVI. Future of AI in India\n- Predictions for the future of AI in India\n- Potential impact of AI on the Indian economy and society\n- Opportunities for innovation and growth in the AI sector\n\nVII. Conclusion\n- Recap of key points discussed in the blog\n- Final thoughts on the rise of AI in India and its implications for the future.', 'content': 'Artificial Intelligence (AI) has been a buzzword in the tech industry for quite some time now. With advancements in technology and data analytics, AI is becoming increasingly popular in various sectors around the world. Its applications range from healthcare to finance to agriculture, revolutionizing the way tasks are performed and decisions are made.\n\nIn India, the rise of AI is no different. While the country may have been a late bloomer in the AI race compared to other developed nations, it is quickly catching up. In this blog post, we will explore the current state of AI in India, its growth trajectory, applications across different industries, challenges and opportunities, and predictions for the future.\n\n**Overview of AI in India**\nIndia has been a hub for technology and innovation, with a rapidly growing tech ecosystem. The AI market in India is estimated to reach $6.4 billion by 2025, with a CAGR of 28.4%. Various industries such as healthcare, agriculture, education, finance, manufacturing, and e-commerce are leveraging AI to improve efficiency, accuracy, and decision-making processes.\n\nSome of the major players in the Indian AI market include tech giants like Google, Microsoft, IBM, and Indian startups like Zomato, Flipkart, and Ola. These companies are investing heavily in AI research and development, aiming to create innovative solutions to address the diverse needs of Indian consumers.\n\n**Growth of AI in India**\nSeveral factors are contributing to the rise of AI in India. The government has launched initiatives like the National AI Portal and the National AI Strategy, aiming to promote AI research, development, and adoption across different sectors. Additionally, investments in AI startups and research institutions are on the rise, attracting funding from both Indian and international investors.\n\n**Applications of AI in India**\nAI is being utilized in various sectors in India to address challenges and improve operations. In healthcare, AI is being used for diagnostics, personalized medicine, and predicting disease outbreaks. In agriculture, AI-powered solutions are helping farmers optimize crop yields, manage resources efficiently, and combat climate change. In education, AI is transforming the way students learn and teachers teach, making education more accessible and engaging. In finance, AI is used for fraud detection, risk management, and customer service. In manufacturing, AI is used for predictive maintenance, quality control, and supply chain management. In e-commerce, AI is used for personalized recommendations, inventory management, and customer service.\n\n**Challenges and Opportunities**\nWhile the growth of AI in India is promising, there are challenges that need to be addre ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
# - Brief history of artificial intelligence (AI) and its growth worldwide
# - Explanation of what AI is and its various applications
#
# II. Overview of AI in India
# - Current state of AI in India
# - Statistics on AI adoption in different industries
# - Major players in the Indian AI market
#
# III. Growth of AI in India
# - Factors contributing to the rise of AI in India
# - Government initiatives and policies promoting AI
# - Investments in AI startups and research institutions
#
# IV. Applications of AI in India
# - AI in healthcare
# - AI in agriculture
# - AI in education
# - AI in finance
# - AI in manufacturing
# - AI in e-commerce
#
# V. Challenges and Opportunities
# - Challenges faced by AI in India
# - Opportunities for growth and development in the Indian AI market
# - Ethical considerations and concerns related to AI
#
# VI. Future of AI in India
# - Predictions for the future of AI in India
# - Potential impact of AI on the Indian economy and society
# - Opportunities for innovation and growth in the AI sector
#
# VII. Conclusion
# - Recap of key points discussed in the blog
# - Final thoughts on the rise of AI in India and its implications for the future.

# %%
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) has been a buzzword in the tech industry for quite some time now. With advancements in technology and data analytics, AI is becoming increasingly popular in various sectors around the world. Its applications range from healthcare to finance to agriculture, revolutionizing the way tasks are performed and decisions are made.
#
# In India, the rise of AI is no different. While the country may have been a late bloomer in the AI race compared to other developed nations, it is quickly catching up. In this blog post, we will explore the current state of AI in India, its growth trajectory, applications across different industries, challenges and opportunities, and predictions for the future.
#
# **Overview of AI in India**
# India has been a hub for technology and innovation, with a rapidly growing tech ecosystem. The AI market in India is estimated to reach $6.4 billion by 2025, with a CAGR of 28.4%. Various industries such as healthcare, agriculture, education, finance, manufacturing, and e-commerce are leveraging AI to improve efficiency, accuracy, and decision-making processes.
#
# Some of the major players in the Indian AI market include tech giants like Google, Microsoft, IBM, and Indian startups like Zomato, Flipkart, and Ola. These companies are investing heavily in AI research and development, aiming to create innovative solutions to address the diverse needs of Indian consumers.
#
# **Growth of AI in India**
# Several factors are contributing to the rise of AI in India. The government has launched initiatives like the National AI Portal and the National AI Strategy, aiming to promote AI research, development, and adoption across different sectors. Additionally, investments in AI startups and research institutions are on the rise, attracting funding from both Indian and international investors.
#
# **Applications of AI in India**
# AI is being utilized in various sectors in India to address challenges and improve operations. In healthcare, AI is being used for diagnostics, personalized medicine, and predicting disease outbreaks. In agriculture, AI-powered solutions are helping farmers optimize crop yields, manage resources efficiently, and combat climate change. In education, AI is transforming the way students learn and teachers teach, making education more accessible and engaging. In finance, AI is used for fraud detection, risk management, and customer service. In manufacturing, AI is used for predictive maintenance, quality control, and supply chain management. In e-commerce, AI is used for personalized recommendations, inventory management, and customer service.
#
# **Challenges and Opportunities**
# While the growth of AI in India is promising, there are challenges that need to be addressed. These include data privacy and security concerns, lack of skilled professionals, ethical considerations, and bias in AI algorithms. However, there are ample opportunities for growth and development in the Indian AI market. With the right investments, policies, and collaborations, AI has the potential to drive innovation, create jobs, and boost economic growth in the country.
#
# **Future of AI in India**
# The future of AI in India looks bright. Predictions suggest that AI will continue to grow and transform various industries, leading to increased productivity and efficiency. The potential impact of AI on the Indian economy and society is immense, with opportunities for innovation and growth in the AI sector. However, it is crucial to address ethical considerations and ensure that AI technologies are used responsibly and for the benefit of all.
#
# **Conclusion**
# In conclusion, the rise of AI in India is inevitable. With the right investments, policies, and collaborations, AI has the potential to revolutionize the way we work, live, and interact. As the Indian AI market continues to grow, it is essential for stakeholders to work together to address challenges, leverage opportunities, and ensure a sustainable and equitable future for AI in India. The journey towards a smarter and more connected India has begun, and the possibilities are endless.
